# %%
#!/usr/bin/env python

import tensorflow as tf
import cv2
import sys
sys.path.append("Wrapped Game Code/")
import pong_fun # whichever is imported "as game" will be used
import dummy_game
import tetris_fun as game
import random
import numpy as np
from collections import deque

GAME = 'tetris' # the name of the game being played for log files
ACTIONS = 6 # number of valid actions
GAMMA = 0.99 # decay rate of past observations
OBSERVE = 1500. # timesteps to observe before training
EXPLORE = 1000. # frames over which to anneal epsilon
FINAL_EPSILON = 0.05 # final value of epsilon
INITIAL_EPSILON = 1.0 # starting value of epsilon
REPLAY_MEMORY = 590000 # number of previous transitions to remember
BATCH = 32 # size of minibatch
K = 1 # only select an action every Kth frame, repeat prev for others

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev = 0.01)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.01, shape = shape)
    return tf.Variable(initial)

def conv2d(x, W, stride):
    return tf.nn.conv2d(x, W, strides = [1, stride, stride, 1], padding = "SAME")

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = "SAME")

def createNetwork():
    # network weights
    W_conv1 = weight_variable([8, 8, 4, 32])
    b_conv1 = bias_variable([32])

    W_conv2 = weight_variable([4, 4, 32, 64])
    b_conv2 = bias_variable([64])

    W_conv3 = weight_variable([3, 3, 64, 64])
    b_conv3 = bias_variable([64])
    
    W_fc1 = weight_variable([1600, 512])
    b_fc1 = bias_variable([512])

    W_fc2 = weight_variable([512, ACTIONS])
    b_fc2 = bias_variable([ACTIONS])

    # input layer
    s = tf.placeholder("float", [None, 80, 80, 4])

    # hidden layers
    h_conv1 = tf.nn.sigmoid(conv2d(s, W_conv1, 4) + b_conv1)
    h_conv1=h_conv1*(conv2d(s, W_conv1, 4) + b_conv1)
    
    h_pool1 = max_pool_2x2(h_conv1)

    h_conv2 = tf.nn.sigmoid(conv2d(h_pool1, W_conv2, 2) + b_conv2)
    h_conv2 = h_conv2*(conv2d(h_pool1, W_conv2, 2) + b_conv2)
    #h_pool2 = max_pool_2x2(h_conv2)

    h_conv3 = tf.nn.sigmoid(conv2d(h_conv2, W_conv3, 1) + b_conv3)
    h_conv3 = h_conv3*(conv2d(h_conv2, W_conv3, 1) + b_conv3)
    #h_pool3 = max_pool_2x2(h_conv3)

    #h_pool3_flat = tf.reshape(h_pool3, [-1, 256])
    h_conv3_flat = tf.reshape(h_conv3, [-1, 1600])

    h_fc1 = tf.nn.relu(tf.matmul(h_conv3_flat, W_fc1) + b_fc1)

    # readout layer
    readout = tf.matmul(h_fc1, W_fc2) + b_fc2
    
    tf.Summary

    return s, readout, h_fc1

def trainNetwork(s, readout, h_fc1, sess):
    # define the cost function
    a = tf.placeholder("float", [None, ACTIONS])
    y = tf.placeholder("float", [None])
    readout_action = tf.reduce_sum(tf.multiply(readout, a), reduction_indices = 1)
    cost = tf.reduce_mean(tf.square(y - readout_action))
    train_step = tf.train.AdamOptimizer(1e-6).minimize(cost)

    # open up a game state to communicate with emulator
    game_state = game.GameState()
#########################################Observing####################################################
    # store the previous observations in replay memory
    D = deque()

    # printing
    a_file = open("logs_" + GAME + "/readout.txt", 'w')
    h_file = open("logs_" + GAME + "/hidden.txt", 'w')

    # get the first state by doing nothing and preprocess the image to 80x80x4
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] = 1
    x_t, r_0, terminal = game_state.frame_step(do_nothing)
    x_t = cv2.cvtColor(cv2.resize(x_t, (80, 80)), cv2.COLOR_BGR2GRAY)
    ret, x_t = cv2.threshold(x_t,1,255,cv2.THRESH_BINARY)
    s_t = np.stack((x_t, x_t, x_t, x_t), axis = 2)

    # saving and loading networks
    saver = tf.train.Saver()
    sess.run(tf.initialize_all_variables())
    checkpoint = tf.train.get_checkpoint_state("saved_networks")
    if checkpoint and checkpoint.model_checkpoint_path:
        saver.restore(sess, checkpoint.model_checkpoint_path)
        print "Successfully loaded:", checkpoint.model_checkpoint_path
    else:
        print "Could not find old network weights"

    epsilon = INITIAL_EPSILON
    t = 0
    while "pigs" != "fly":
        # choose an action epsilon greedily
        readout_t = readout.eval(feed_dict = {s : [s_t]})[0]
        a_t = np.zeros([ACTIONS])
        action_index = 0
        if random.random() <= epsilon or t <= OBSERVE:
            action_index = random.randrange(ACTIONS)
            a_t[action_index] = 1
        else:
            action_index = np.argmax(readout_t)
            a_t[action_index] = 1

        # scale down epsilon
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        for i in range(0, K):
            # run the selected action and observe next state and reward
            x_t1_col, r_t, terminal = game_state.frame_step(a_t)
            x_t1 = cv2.cvtColor(cv2.resize(x_t1_col, (80, 80)), cv2.COLOR_BGR2GRAY)
            ret, x_t1 = cv2.threshold(x_t1,1,255,cv2.THRESH_BINARY)
            x_t1 = np.reshape(x_t1, (80, 80, 1))
            s_t1 = np.append(x_t1, s_t[:,:,0:3], axis = 2)

            # store the transition in D
            D.append((s_t, a_t, r_t, s_t1, terminal))
            if len(D) > REPLAY_MEMORY:
                D.popleft()

        # only train if done observing
        if t > OBSERVE:
            print("finish observe")
            # sample a minibatch to train on
            minibatch = random.sample(D, BATCH)

            # get the batch variables
            s_j_batch = [d[0] for d in minibatch]
            a_batch = [d[1] for d in minibatch]
            r_batch = [d[2] for d in minibatch]
            s_j1_batch = [d[3] for d in minibatch]

            y_batch = []
            readout_j1_batch = readout.eval(feed_dict = {s : s_j1_batch})
            for i in range(0, len(minibatch)):
                # if terminal only equals reward
                if minibatch[i][4]:
                    y_batch.append(r_batch[i])
                else:
                    y_batch.append(r_batch[i] + GAMMA * np.max(readout_j1_batch[i]))

            # perform gradient step
            train_step.run(feed_dict = {
                y : y_batch,
                a : a_batch,
                s : s_j_batch})

        # update the old values
        s_t = s_t1
        t += 1

        # save progress every 10000 iterations
        #if t % 10000 == 0:
         
#   saver.save(sess, 'saved_networks/' + GAME + '-dqn', global_step = t)

        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"
        print "TIMESTEP", t, "/ STATE", state, "/ LINES", game_state.total_lines, "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, "/ Q_MAX %e" % np.max(readout_t)

        # write info to files
        '''
        if t % 10000 <= 100:
            a_file.write(",".join([str(x) for x in readout_t]) + '\n')
            h_file.write(",".join([str(x) for x in h_fc1.eval(feed_dict={s:[s_t]})[0]]) + '\n')
            cv2.imwrite("logs_tetris/frame" + str(t) + ".png", x_t1)
        '''

def playGame():
    sess = tf.InteractiveSession()
    s, readout, h_fc1 = createNetwork()
    trainNetwork(s, readout, h_fc1, sess)

def main():
    playGame()

if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From <ipython-input-1-654629ce7f7f>:113: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Could not find old network weights
# TIMESTEP 1 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 20 / Q_MAX 1.927630e-02
# TIMESTEP 2 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 20 / Q_MAX 1.904104e-02
# TIMESTEP 3 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 14 / Q_MAX 1.852517e-02
# TIMESTEP 4 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 17 / Q_MAX 1.815628e-02
# TIMESTEP 5 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 17 / Q_MAX 1.790401e-02
# TIMESTEP 6 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 17 / Q_MAX 1.930744e-02
# TIMESTEP 7 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 17 / Q_MAX 1.873290e-02
# TIMESTEP 8 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 17 / Q_MAX 1.838798e-02
# TIMESTEP 9 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 17 / Q_MAX 1.873786e-02
# TIMESTEP 10 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 17 / Q_MAX 2.066814e-02
# TIMESTEP 11 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 17 / Q_MAX 1.737795e-02
# TIMESTEP 12 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 17 / Q_MAX 1.817581e-02
# TIMESTEP 13 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 17 / Q_MAX 1.795611e-02
# TIMESTEP 14 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 17 / Q_MAX 1.752942e-02
# TIMESTEP 15 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 17 / Q_MAX 1.935194e-02
# TIMESTEP 16 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 17 / Q_MAX 1.979682e-02
# TIMESTEP 17 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 17 / Q_MAX 2.044775e-02
# TIMESTEP 18 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 17 / Q_MAX 1.935645e-02
# TIMESTEP 19 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 13 / Q_MAX 2.234859e-02
# TIMESTEP 20 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 15 / Q_MAX 1.907318e-02
# TIMESTEP 21 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 15 / Q_MAX 1.901279e-02
# TIMESTEP 22 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 15 / Q_MAX 1.917210e-02
# TIMESTEP 23 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 15 / Q_MAX 1.942742e-02
# TIMESTEP 24 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 15 / Q_MAX 1.625640e-02
# TIMESTEP 25 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 15 / Q_MAX 1.748963e-02
# TIMESTEP 26 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 15 / Q_MAX 1.652913e-02
# TIMESTEP 27 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 15 / Q_MAX 1.756037e-02
# TIMESTEP 28 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 11 / Q_MAX 1.734623e-02
# TIMESTEP 29 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 13 / Q_MAX 1.546045e-02
# TIMESTEP 30 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 13 / Q_MAX 1.384131e-02
# TIMESTEP 31 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 13 / Q_MAX 1.575290e-02
# TIMESTEP 32 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 13 / Q_MAX 1.574199e-02
# TIMESTEP 33 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 13 / Q_MAX 1.512896e-02
# TIMESTEP 34 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 13 / Q_MAX 1.721756e-02
# TIMESTEP 35 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 13 / Q_MAX 1.593504e-02
# TIMESTEP 36 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 13 / Q_MAX 1.566124e-02
# TIMESTEP 37 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 13 / Q_MAX 1.546387e-02
# TIMESTEP 38 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 13 / Q_MAX 1.649781e-02
# TIMESTEP 39 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 11 / Q_MAX 1.676150e-02
# TIMESTEP 40 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 12 / Q_MAX 1.682482e-02
# TIMESTEP 41 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 12 / Q_MAX 1.703606e-02
# TIMESTEP 42 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 12 / Q_MAX 1.611649e-02
# TIMESTEP 43 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 12 / Q_MAX 1.588359e-02
# TIMESTEP 44 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 12 / Q_MAX 1.537428e-02
# TIMESTEP 45 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 12 / Q_MAX 1.536697e-02
# TIMESTEP 46 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 12 / Q_MAX 1.577947e-02
# TIMESTEP 47 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 10 / Q_MAX 1.594777e-02
# TIMESTEP 48 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 7 / Q_MAX 1.673586e-02
# TIMESTEP 49 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 5 / Q_MAX 1.467462e-02
# TIMESTEP 50 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 7 / Q_MAX 1.503053e-02
# TIMESTEP 51 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 7 / Q_MAX 1.843023e-02
# TIMESTEP 52 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 7 / Q_MAX 1.741748e-02
# TIMESTEP 53 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 7 / Q_MAX 1.920513e-02
# TIMESTEP 54 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 5 / Q_MAX 1.622659e-02
# TIMESTEP 55 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 6 / Q_MAX 1.676714e-02
# TIMESTEP 56 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 6 / Q_MAX 1.820990e-02
# TIMESTEP 57 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 6 / Q_MAX 2.022285e-02
# TIMESTEP 58 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 2 / Q_MAX 1.994620e-02
# TIMESTEP 59 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 4 / Q_MAX 2.306953e-02
# TIMESTEP 60 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 4 / Q_MAX 2.391078e-02
# TIMESTEP 61 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 4 / Q_MAX 2.117558e-02
# TIMESTEP 62 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 4 / Q_MAX 1.978553e-02
# TIMESTEP 63 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 0 / Q_MAX 1.727833e-02
# TIMESTEP 64 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 0 / Q_MAX 1.495669e-02
# TIMESTEP 65 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 20 / Q_MAX 1.655966e-02
# TIMESTEP 66 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 20 / Q_MAX 1.487947e-02
# TIMESTEP 67 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 20 / Q_MAX 1.415179e-02
# TIMESTEP 68 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 16 / Q_MAX 1.471809e-02
# TIMESTEP 69 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 18 / Q_MAX 1.725409e-02
# TIMESTEP 70 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 18 / Q_MAX 1.638270e-02
# TIMESTEP 71 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 18 / Q_MAX 1.763375e-02
# TIMESTEP 72 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 12 / Q_MAX 1.967606e-02
# TIMESTEP 73 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 15 / Q_MAX 1.942134e-02
# TIMESTEP 74 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 15 / Q_MAX 1.710992e-02
# TIMESTEP 75 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 15 / Q_MAX 1.812515e-02
# TIMESTEP 76 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 15 / Q_MAX 1.688342e-02
# TIMESTEP 77 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 11 / Q_MAX 1.773714e-02
# TIMESTEP 78 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 5 / Q_MAX 1.749539e-02
# TIMESTEP 79 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 9 / Q_MAX 1.562050e-02
# TIMESTEP 80 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 9 / Q_MAX 1.638997e-02
# TIMESTEP 81 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 9 / Q_MAX 1.663186e-02
# TIMESTEP 82 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 9 / Q_MAX 1.685734e-02
# TIMESTEP 83 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 9 / Q_MAX 1.511557e-02
# TIMESTEP 84 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 9 / Q_MAX 1.475584e-02
# TIMESTEP 85 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 9 / Q_MAX 1.442612e-02
# TIMESTEP 86 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 9 / Q_MAX 1.632572e-02
# TIMESTEP 87 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 9 / Q_MAX 1.583025e-02
# TIMESTEP 88 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 5 / Q_MAX 1.646435e-02
# TIMESTEP 89 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 7 / Q_MAX 1.453421e-02
# TIMESTEP 90 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 7 / Q_MAX 1.591691e-02
# TIMESTEP 91 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 7 / Q_MAX 1.612957e-02
# TIMESTEP 92 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 5 / Q_MAX 1.876991e-02
# TIMESTEP 93 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 6 / Q_MAX 1.686240e-02
# TIMESTEP 94 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 2 / Q_MAX 1.661696e-02
# TIMESTEP 95 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 0 / Q_MAX 1.697790e-02
# TIMESTEP 96 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 2 / Q_MAX 1.683154e-02
# TIMESTEP 97 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 2 / Q_MAX 1.773493e-02
# TIMESTEP 98 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 2 / Q_MAX 1.681164e-02
# TIMESTEP 99 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 2 / Q_MAX 1.832430e-02
# TIMESTEP 100 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 0 / Q_MAX 1.608585e-02
# TIMESTEP 101 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 18 / Q_MAX 1.594833e-02
# TIMESTEP 102 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 19 / Q_MAX 1.574722e-02
# TIMESTEP 103 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 19 / Q_MAX 1.707199e-02
# TIMESTEP 104 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 17 / Q_MAX 1.383751e-02
# TIMESTEP 105 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 18 / Q_MAX 1.815349e-02
# TIMESTEP 106 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 14 / Q_MAX 1.817927e-02
# TIMESTEP 107 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 16 / Q_MAX 1.555143e-02
# TIMESTEP 108 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.738955e-02
# TIMESTEP 109 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 16 / Q_MAX 1.785354e-02
# TIMESTEP 110 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 16 / Q_MAX 1.749079e-02
# TIMESTEP 111 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 16 / Q_MAX 1.651700e-02
# TIMESTEP 112 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.754060e-02
# TIMESTEP 113 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 16 / Q_MAX 1.752451e-02
# TIMESTEP 114 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.789428e-02
# TIMESTEP 115 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 16 / Q_MAX 1.491489e-02
# TIMESTEP 116 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.518701e-02
# TIMESTEP 117 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.564692e-02
# TIMESTEP 118 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.671993e-02
# TIMESTEP 119 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.793983e-02
# TIMESTEP 120 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 16 / Q_MAX 1.757750e-02
# TIMESTEP 121 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 16 / Q_MAX 1.597551e-02
# TIMESTEP 122 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.558846e-02
# TIMESTEP 123 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.800260e-02
# TIMESTEP 124 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.603767e-02
# TIMESTEP 125 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.804659e-02
# TIMESTEP 126 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.571567e-02
# TIMESTEP 127 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.472474e-02
# TIMESTEP 128 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.582553e-02
# TIMESTEP 129 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.711434e-02
# TIMESTEP 130 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 16 / Q_MAX 1.656259e-02
# TIMESTEP 131 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 16 / Q_MAX 1.623905e-02
# TIMESTEP 132 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 16 / Q_MAX 1.666122e-02
# TIMESTEP 133 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 16 / Q_MAX 1.589179e-02
# TIMESTEP 134 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 16 / Q_MAX 1.782407e-02
# TIMESTEP 135 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.764382e-02
# TIMESTEP 136 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.853367e-02
# TIMESTEP 137 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.738214e-02
# TIMESTEP 138 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 16 / Q_MAX 1.971722e-02
# TIMESTEP 139 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.908077e-02
# TIMESTEP 140 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 16 / Q_MAX 1.630270e-02
# TIMESTEP 141 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.610892e-02
# TIMESTEP 142 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.893614e-02
# TIMESTEP 143 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.935276e-02
# TIMESTEP 144 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 2.133306e-02
# TIMESTEP 145 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 16 / Q_MAX 2.271789e-02
# TIMESTEP 146 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 12 / Q_MAX 1.830959e-02
# TIMESTEP 147 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 14 / Q_MAX 2.177819e-02
# TIMESTEP 148 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 14 / Q_MAX 1.864290e-02
# TIMESTEP 149 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 14 / Q_MAX 1.655926e-02
# TIMESTEP 150 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 14 / Q_MAX 1.657487e-02
# TIMESTEP 151 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 14 / Q_MAX 1.700985e-02
# TIMESTEP 152 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 14 / Q_MAX 1.772338e-02
# TIMESTEP 153 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 8 / Q_MAX 1.812845e-02
# TIMESTEP 154 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 11 / Q_MAX 1.586633e-02
# TIMESTEP 155 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 11 / Q_MAX 1.603051e-02
# TIMESTEP 156 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 11 / Q_MAX 1.613036e-02
# TIMESTEP 157 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 11 / Q_MAX 1.707159e-02
# TIMESTEP 158 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 11 / Q_MAX 1.635589e-02
# TIMESTEP 159 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 11 / Q_MAX 1.599339e-02
# TIMESTEP 160 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 11 / Q_MAX 1.540744e-02
# TIMESTEP 161 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 11 / Q_MAX 1.655042e-02
# TIMESTEP 162 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 11 / Q_MAX 1.578439e-02
# TIMESTEP 163 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 11 / Q_MAX 1.740857e-02
# TIMESTEP 164 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 11 / Q_MAX 1.776568e-02
# TIMESTEP 165 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 9 / Q_MAX 1.883085e-02
# TIMESTEP 166 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 8 / Q_MAX 1.790786e-02
# TIMESTEP 167 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 9 / Q_MAX 1.786140e-02
# TIMESTEP 168 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 9 / Q_MAX 1.585806e-02
# TIMESTEP 169 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 9 / Q_MAX 1.391688e-02
# TIMESTEP 170 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 9 / Q_MAX 1.483414e-02
# TIMESTEP 171 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 9 / Q_MAX 1.651578e-02
# TIMESTEP 172 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 9 / Q_MAX 1.409208e-02
# TIMESTEP 173 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 9 / Q_MAX 1.397138e-02
# TIMESTEP 174 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 9 / Q_MAX 1.710916e-02
# TIMESTEP 175 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 9 / Q_MAX 1.515456e-02
# TIMESTEP 176 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 9 / Q_MAX 1.513992e-02
# TIMESTEP 177 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 9 / Q_MAX 1.478103e-02
# TIMESTEP 178 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 9 / Q_MAX 1.436686e-02
# TIMESTEP 179 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 9 / Q_MAX 1.760429e-02
# TIMESTEP 180 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 5 / Q_MAX 1.593508e-02
# TIMESTEP 181 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 7 / Q_MAX 1.770528e-02
# TIMESTEP 182 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 7 / Q_MAX 1.868479e-02
# TIMESTEP 183 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 3 / Q_MAX 1.867323e-02
# TIMESTEP 184 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 5 / Q_MAX 1.863761e-02
# TIMESTEP 185 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 5 / Q_MAX 1.817820e-02
# TIMESTEP 186 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 5 / Q_MAX 1.783394e-02
# TIMESTEP 187 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 5 / Q_MAX 1.930821e-02
# TIMESTEP 188 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 5 / Q_MAX 1.945638e-02
# TIMESTEP 189 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 5 / Q_MAX 1.560525e-02
# TIMESTEP 190 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 5 / Q_MAX 1.808856e-02
# TIMESTEP 191 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 5 / Q_MAX 1.784442e-02
# TIMESTEP 192 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 5 / Q_MAX 1.836141e-02
# TIMESTEP 193 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 5 / Q_MAX 1.658604e-02
# TIMESTEP 194 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 5 / Q_MAX 1.634317e-02
# TIMESTEP 195 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 5 / Q_MAX 1.851054e-02
# TIMESTEP 196 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 5 / Q_MAX 1.793107e-02
# TIMESTEP 197 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 5 / Q_MAX 1.798613e-02
# TIMESTEP 198 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 5 / Q_MAX 1.728620e-02
# TIMESTEP 199 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 5 / Q_MAX 1.575027e-02
# TIMESTEP 200 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 5 / Q_MAX 1.437296e-02
# TIMESTEP 201 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 5 / Q_MAX 1.557912e-02
# TIMESTEP 202 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 5 / Q_MAX 1.572650e-02
# TIMESTEP 203 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 5 / Q_MAX 1.629179e-02
# TIMESTEP 204 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 1 / Q_MAX 1.647108e-02
# TIMESTEP 205 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD -1 / Q_MAX 1.631953e-02
# TIMESTEP 206 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 0 / Q_MAX 1.634298e-02
# TIMESTEP 207 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 20 / Q_MAX 1.529024e-02
# TIMESTEP 208 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 20 / Q_MAX 1.558649e-02
# TIMESTEP 209 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 14 / Q_MAX 1.387756e-02
# TIMESTEP 210 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 17 / Q_MAX 1.886330e-02
# TIMESTEP 211 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 17 / Q_MAX 1.848189e-02
# TIMESTEP 212 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 17 / Q_MAX 1.723003e-02
# TIMESTEP 213 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 17 / Q_MAX 1.869998e-02
# TIMESTEP 214 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 17 / Q_MAX 1.743346e-02
# TIMESTEP 215 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 17 / Q_MAX 1.661613e-02
# TIMESTEP 216 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 17 / Q_MAX 1.697576e-02
# TIMESTEP 217 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 17 / Q_MAX 1.769865e-02
# TIMESTEP 218 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 15 / Q_MAX 1.826282e-02
# TIMESTEP 219 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 16 / Q_MAX 1.679284e-02
# TIMESTEP 220 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.500126e-02
# TIMESTEP 221 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 16 / Q_MAX 1.778769e-02
# TIMESTEP 222 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.589699e-02
# TIMESTEP 223 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 12 / Q_MAX 1.770740e-02
# TIMESTEP 224 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 12 / Q_MAX 1.953520e-02
# TIMESTEP 225 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 13 / Q_MAX 1.615971e-02
# TIMESTEP 226 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 13 / Q_MAX 1.605048e-02
# TIMESTEP 227 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 13 / Q_MAX 1.729082e-02
# TIMESTEP 228 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 13 / Q_MAX 1.810051e-02
# TIMESTEP 229 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 7 / Q_MAX 1.883978e-02
# TIMESTEP 230 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 10 / Q_MAX 2.071250e-02
# TIMESTEP 231 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 10 / Q_MAX 1.819431e-02
# TIMESTEP 232 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 10 / Q_MAX 1.897748e-02
# TIMESTEP 233 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 10 / Q_MAX 2.136934e-02
# TIMESTEP 234 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 10 / Q_MAX 2.141101e-02
# TIMESTEP 235 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 10 / Q_MAX 1.910089e-02
# TIMESTEP 236 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 10 / Q_MAX 1.875492e-02
# TIMESTEP 237 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 10 / Q_MAX 1.998526e-02
# TIMESTEP 238 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 10 / Q_MAX 1.790975e-02
# TIMESTEP 239 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 10 / Q_MAX 2.065583e-02
# TIMESTEP 240 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 10 / Q_MAX 2.254668e-02
# TIMESTEP 241 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 10 / Q_MAX 2.105710e-02
# TIMESTEP 242 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 10 / Q_MAX 1.913307e-02
# TIMESTEP 243 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 8 / Q_MAX 1.927545e-02
# TIMESTEP 244 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 9 / Q_MAX 1.934845e-02
# TIMESTEP 245 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 3 / Q_MAX 1.826978e-02
# TIMESTEP 246 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 6 / Q_MAX 1.956761e-02
# TIMESTEP 247 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 6 / Q_MAX 2.136060e-02
# TIMESTEP 248 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 6 / Q_MAX 2.073541e-02
# TIMESTEP 249 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 4 / Q_MAX 2.354122e-02
# TIMESTEP 250 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 1 / Q_MAX 2.243286e-02
# TIMESTEP 251 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 3 / Q_MAX 2.352500e-02
# TIMESTEP 252 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD -1 / Q_MAX 2.188734e-02
# TIMESTEP 253 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 0 / Q_MAX 2.040393e-02
# TIMESTEP 254 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 20 / Q_MAX 1.853931e-02
# TIMESTEP 255 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 20 / Q_MAX 1.635038e-02
# TIMESTEP 256 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 20 / Q_MAX 1.620640e-02
# TIMESTEP 257 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 20 / Q_MAX 1.659823e-02
# TIMESTEP 258 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 20 / Q_MAX 2.148947e-02
# TIMESTEP 259 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 20 / Q_MAX 2.080551e-02
# TIMESTEP 260 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 20 / Q_MAX 1.912618e-02
# TIMESTEP 261 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 20 / Q_MAX 2.036161e-02
# TIMESTEP 262 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 20 / Q_MAX 2.079234e-02
# TIMESTEP 263 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 20 / Q_MAX 2.063760e-02
# TIMESTEP 264 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 16 / Q_MAX 1.902043e-02
# TIMESTEP 265 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 18 / Q_MAX 1.895835e-02
# TIMESTEP 266 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 18 / Q_MAX 1.786621e-02
# TIMESTEP 267 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 18 / Q_MAX 2.099388e-02
# TIMESTEP 268 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 18 / Q_MAX 1.863989e-02
# TIMESTEP 269 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 18 / Q_MAX 1.676798e-02
# TIMESTEP 270 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 18 / Q_MAX 1.771071e-02
# TIMESTEP 271 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 18 / Q_MAX 1.690672e-02
# TIMESTEP 272 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 18 / Q_MAX 1.752996e-02
# TIMESTEP 273 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 18 / Q_MAX 1.693860e-02
# TIMESTEP 274 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 18 / Q_MAX 1.653285e-02
# TIMESTEP 275 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 18 / Q_MAX 1.795626e-02
# TIMESTEP 276 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 18 / Q_MAX 1.784432e-02
# TIMESTEP 277 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 18 / Q_MAX 1.605981e-02
# TIMESTEP 278 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 18 / Q_MAX 1.621662e-02
# TIMESTEP 279 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 18 / Q_MAX 1.468080e-02
# TIMESTEP 280 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 18 / Q_MAX 1.472417e-02
# TIMESTEP 281 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 18 / Q_MAX 1.557110e-02
# TIMESTEP 282 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 18 / Q_MAX 1.692251e-02
# TIMESTEP 283 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 18 / Q_MAX 1.595567e-02
# TIMESTEP 284 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 14 / Q_MAX 1.583229e-02
# TIMESTEP 285 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.701890e-02
# TIMESTEP 286 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 16 / Q_MAX 1.779555e-02
# TIMESTEP 287 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 16 / Q_MAX 1.836871e-02
# TIMESTEP 288 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.769176e-02
# TIMESTEP 289 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.717049e-02
# TIMESTEP 290 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.959046e-02
# TIMESTEP 291 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.814979e-02
# TIMESTEP 292 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 16 / Q_MAX 1.956489e-02
# TIMESTEP 293 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.776098e-02
# TIMESTEP 294 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 12 / Q_MAX 1.757426e-02
# TIMESTEP 295 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 14 / Q_MAX 2.003468e-02
# TIMESTEP 296 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 14 / Q_MAX 1.666733e-02
# TIMESTEP 297 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 14 / Q_MAX 1.821536e-02
# TIMESTEP 298 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 14 / Q_MAX 1.621509e-02
# TIMESTEP 299 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 14 / Q_MAX 1.664688e-02
# TIMESTEP 300 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 14 / Q_MAX 1.668124e-02
# TIMESTEP 301 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 14 / Q_MAX 1.514263e-02
# TIMESTEP 302 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 10 / Q_MAX 1.665858e-02
# TIMESTEP 303 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 8 / Q_MAX 1.805882e-02
# TIMESTEP 304 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 10 / Q_MAX 1.585016e-02
# TIMESTEP 305 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 10 / Q_MAX 1.710063e-02
# TIMESTEP 306 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 10 / Q_MAX 1.894651e-02
# TIMESTEP 307 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 10 / Q_MAX 1.801040e-02
# TIMESTEP 308 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 10 / Q_MAX 1.685300e-02
# TIMESTEP 309 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 6 / Q_MAX 1.703237e-02
# TIMESTEP 310 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 8 / Q_MAX 1.608307e-02
# TIMESTEP 311 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 8 / Q_MAX 1.919913e-02
# TIMESTEP 312 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 8 / Q_MAX 1.908093e-02
# TIMESTEP 313 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 8 / Q_MAX 1.724902e-02
# TIMESTEP 314 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 8 / Q_MAX 1.674546e-02
# TIMESTEP 315 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 4 / Q_MAX 1.532260e-02
# TIMESTEP 316 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 6 / Q_MAX 1.713215e-02
# TIMESTEP 317 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 6 / Q_MAX 1.841973e-02
# TIMESTEP 318 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 6 / Q_MAX 1.881371e-02
# TIMESTEP 319 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 6 / Q_MAX 1.871585e-02
# TIMESTEP 320 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 6 / Q_MAX 1.838866e-02
# TIMESTEP 321 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 6 / Q_MAX 1.986710e-02
# TIMESTEP 322 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 6 / Q_MAX 1.798263e-02
# TIMESTEP 323 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 6 / Q_MAX 1.752377e-02
# TIMESTEP 324 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 6 / Q_MAX 1.675913e-02
# TIMESTEP 325 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 6 / Q_MAX 1.815564e-02
# TIMESTEP 326 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 6 / Q_MAX 1.693295e-02
# TIMESTEP 327 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 6 / Q_MAX 1.737077e-02
# TIMESTEP 328 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 6 / Q_MAX 1.778237e-02
# TIMESTEP 329 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 6 / Q_MAX 1.701021e-02
# TIMESTEP 330 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 4 / Q_MAX 1.572387e-02
# TIMESTEP 331 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 5 / Q_MAX 2.057157e-02
# TIMESTEP 332 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD -1 / Q_MAX 1.874274e-02
# TIMESTEP 333 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD -2 / Q_MAX 2.083203e-02
# TIMESTEP 334 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 0 / Q_MAX 2.005904e-02
# TIMESTEP 335 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 20 / Q_MAX 1.620718e-02
# TIMESTEP 336 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 16 / Q_MAX 1.697948e-02
# TIMESTEP 337 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 18 / Q_MAX 1.637704e-02
# TIMESTEP 338 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 18 / Q_MAX 1.464481e-02
# TIMESTEP 339 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 18 / Q_MAX 1.663622e-02
# TIMESTEP 340 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 18 / Q_MAX 1.970152e-02
# TIMESTEP 341 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 18 / Q_MAX 1.846621e-02
# TIMESTEP 342 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 18 / Q_MAX 1.842044e-02
# TIMESTEP 343 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 18 / Q_MAX 1.898580e-02
# TIMESTEP 344 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 16 / Q_MAX 2.009301e-02
# TIMESTEP 345 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 15 / Q_MAX 2.027336e-02
# TIMESTEP 346 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 16 / Q_MAX 1.848807e-02
# TIMESTEP 347 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 16 / Q_MAX 1.789205e-02
# TIMESTEP 348 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 16 / Q_MAX 1.868810e-02
# TIMESTEP 349 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.918501e-02
# TIMESTEP 350 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.735549e-02
# TIMESTEP 351 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 16 / Q_MAX 1.786188e-02
# TIMESTEP 352 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 16 / Q_MAX 2.093830e-02
# TIMESTEP 353 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 2.113089e-02
# TIMESTEP 354 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.912223e-02
# TIMESTEP 355 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.623345e-02
# TIMESTEP 356 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.586014e-02
# TIMESTEP 357 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.625156e-02
# TIMESTEP 358 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.605072e-02
# TIMESTEP 359 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.670510e-02
# TIMESTEP 360 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.652715e-02
# TIMESTEP 361 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 14 / Q_MAX 1.696372e-02
# TIMESTEP 362 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 15 / Q_MAX 1.890321e-02
# TIMESTEP 363 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 15 / Q_MAX 1.640072e-02
# TIMESTEP 364 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 15 / Q_MAX 1.645751e-02
# TIMESTEP 365 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 15 / Q_MAX 1.535526e-02
# TIMESTEP 366 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 11 / Q_MAX 1.570828e-02
# TIMESTEP 367 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 13 / Q_MAX 1.577325e-02
# TIMESTEP 368 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 13 / Q_MAX 1.413745e-02
# TIMESTEP 369 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 9 / Q_MAX 1.540171e-02
# TIMESTEP 370 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 11 / Q_MAX 1.278891e-02
# TIMESTEP 371 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 11 / Q_MAX 1.685948e-02
# TIMESTEP 372 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 7 / Q_MAX 1.584191e-02
# TIMESTEP 373 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 9 / Q_MAX 1.535721e-02
# TIMESTEP 374 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 9 / Q_MAX 1.629166e-02
# TIMESTEP 375 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 9 / Q_MAX 1.787973e-02
# TIMESTEP 376 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 9 / Q_MAX 1.739544e-02
# TIMESTEP 377 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 9 / Q_MAX 1.848802e-02
# TIMESTEP 378 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 9 / Q_MAX 1.417471e-02
# TIMESTEP 379 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 9 / Q_MAX 1.781015e-02
# TIMESTEP 380 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 9 / Q_MAX 1.742203e-02
# TIMESTEP 381 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 9 / Q_MAX 1.735120e-02
# TIMESTEP 382 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 9 / Q_MAX 1.818066e-02
# TIMESTEP 383 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 9 / Q_MAX 1.746247e-02
# TIMESTEP 384 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 9 / Q_MAX 1.614336e-02
# TIMESTEP 385 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 9 / Q_MAX 1.841545e-02
# TIMESTEP 386 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 7 / Q_MAX 1.700613e-02
# TIMESTEP 387 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 8 / Q_MAX 1.442897e-02
# TIMESTEP 388 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 8 / Q_MAX 1.656986e-02
# TIMESTEP 389 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 4 / Q_MAX 1.834941e-02
# TIMESTEP 390 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 6 / Q_MAX 1.969095e-02
# TIMESTEP 391 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 6 / Q_MAX 1.906285e-02
# TIMESTEP 392 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 6 / Q_MAX 1.953132e-02
# TIMESTEP 393 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 6 / Q_MAX 1.999256e-02
# TIMESTEP 394 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 6 / Q_MAX 2.041652e-02
# TIMESTEP 395 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 6 / Q_MAX 1.702726e-02
# TIMESTEP 396 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 6 / Q_MAX 1.721260e-02
# TIMESTEP 397 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 6 / Q_MAX 1.659474e-02
# TIMESTEP 398 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 6 / Q_MAX 1.616788e-02
# TIMESTEP 399 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 6 / Q_MAX 1.623878e-02
# TIMESTEP 400 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 6 / Q_MAX 1.675734e-02
# TIMESTEP 401 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 6 / Q_MAX 1.891065e-02
# TIMESTEP 402 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 2 / Q_MAX 1.965864e-02
# TIMESTEP 403 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 4 / Q_MAX 1.626372e-02
# TIMESTEP 404 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 4 / Q_MAX 1.645026e-02
# TIMESTEP 405 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 4 / Q_MAX 1.844664e-02
# TIMESTEP 406 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 4 / Q_MAX 1.837932e-02
# TIMESTEP 407 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 4 / Q_MAX 1.678176e-02
# TIMESTEP 408 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 4 / Q_MAX 1.572286e-02
# TIMESTEP 409 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 4 / Q_MAX 1.568025e-02
# TIMESTEP 410 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 4 / Q_MAX 1.543248e-02
# TIMESTEP 411 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 4 / Q_MAX 1.391346e-02
# TIMESTEP 412 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 2 / Q_MAX 1.485613e-02
# TIMESTEP 413 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 3 / Q_MAX 1.359868e-02
# TIMESTEP 414 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 3 / Q_MAX 1.600296e-02
# TIMESTEP 415 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 3 / Q_MAX 1.692412e-02
# TIMESTEP 416 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 3 / Q_MAX 1.414432e-02
# TIMESTEP 417 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 1 / Q_MAX 1.514810e-02
# TIMESTEP 418 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD -2 / Q_MAX 1.563277e-02
# TIMESTEP 419 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 0 / Q_MAX 1.707424e-02
# TIMESTEP 420 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 20 / Q_MAX 1.735494e-02
# TIMESTEP 421 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 20 / Q_MAX 1.588351e-02
# TIMESTEP 422 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 20 / Q_MAX 1.538901e-02
# TIMESTEP 423 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 20 / Q_MAX 1.332606e-02
# TIMESTEP 424 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 20 / Q_MAX 1.565895e-02
# TIMESTEP 425 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 20 / Q_MAX 1.724064e-02
# TIMESTEP 426 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 20 / Q_MAX 1.694819e-02
# TIMESTEP 427 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 20 / Q_MAX 1.743646e-02
# TIMESTEP 428 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 20 / Q_MAX 1.873918e-02
# TIMESTEP 429 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 12 / Q_MAX 1.754040e-02
# TIMESTEP 430 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 16 / Q_MAX 1.702157e-02
# TIMESTEP 431 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.650557e-02
# TIMESTEP 432 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 16 / Q_MAX 1.691301e-02
# TIMESTEP 433 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.839762e-02
# TIMESTEP 434 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 1.788361e-02
# TIMESTEP 435 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 16 / Q_MAX 2.076835e-02
# TIMESTEP 436 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 16 / Q_MAX 1.725370e-02
# TIMESTEP 437 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 16 / Q_MAX 1.923950e-02
# TIMESTEP 438 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 16 / Q_MAX 2.157180e-02
# TIMESTEP 439 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 16 / Q_MAX 1.935982e-02
# TIMESTEP 440 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 10 / Q_MAX 1.987774e-02
# TIMESTEP 441 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 13 / Q_MAX 1.939553e-02
# TIMESTEP 442 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 13 / Q_MAX 1.693810e-02
# TIMESTEP 443 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 13 / Q_MAX 1.602371e-02
# TIMESTEP 444 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 13 / Q_MAX 1.699363e-02
# TIMESTEP 445 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 13 / Q_MAX 1.730160e-02
# TIMESTEP 446 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 13 / Q_MAX 1.881152e-02
# TIMESTEP 447 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 13 / Q_MAX 1.760572e-02
# TIMESTEP 448 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 13 / Q_MAX 1.837023e-02
# TIMESTEP 449 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 13 / Q_MAX 1.800326e-02
# TIMESTEP 450 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 13 / Q_MAX 1.886754e-02
# TIMESTEP 451 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 13 / Q_MAX 2.020408e-02
# TIMESTEP 452 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 9 / Q_MAX 1.789120e-02
# TIMESTEP 453 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 11 / Q_MAX 1.548079e-02
# TIMESTEP 454 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 9 / Q_MAX 1.741630e-02
# TIMESTEP 455 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 10 / Q_MAX 1.938622e-02
# TIMESTEP 456 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 10 / Q_MAX 1.909195e-02
# TIMESTEP 457 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 10 / Q_MAX 1.923680e-02
# TIMESTEP 458 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 10 / Q_MAX 1.681963e-02
# TIMESTEP 459 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 10 / Q_MAX 1.626879e-02
# TIMESTEP 460 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 10 / Q_MAX 1.477399e-02
# TIMESTEP 461 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 10 / Q_MAX 1.481260e-02
# TIMESTEP 462 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 6 / Q_MAX 1.780140e-02
# TIMESTEP 463 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 8 / Q_MAX 1.473464e-02
# TIMESTEP 464 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 8 / Q_MAX 1.812809e-02
# TIMESTEP 465 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 8 / Q_MAX 1.879935e-02
# TIMESTEP 466 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 8 / Q_MAX 1.911848e-02
# TIMESTEP 467 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 8 / Q_MAX 1.900335e-02
# TIMESTEP 468 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 8 / Q_MAX 1.717325e-02
# TIMESTEP 469 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 5 / REWARD 8 / Q_MAX 1.782223e-02
# TIMESTEP 470 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 8 / Q_MAX 1.945500e-02
# TIMESTEP 471 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 8 / Q_MAX 1.996486e-02
# TIMESTEP 472 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 8 / Q_MAX 2.028538e-02
# TIMESTEP 473 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 8 / Q_MAX 1.830074e-02
# TIMESTEP 474 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 8 / Q_MAX 1.946323e-02
# TIMESTEP 475 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 8 / Q_MAX 1.882283e-02
# TIMESTEP 476 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 8 / Q_MAX 1.988990e-02
# TIMESTEP 477 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD 4 / Q_MAX 1.787724e-02
# TIMESTEP 478 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 4 / REWARD -2 / Q_MAX 1.895872e-02
# TIMESTEP 479 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 0 / Q_MAX 1.908537e-02
# TIMESTEP 480 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 20 / Q_MAX 1.977130e-02
# TIMESTEP 481 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 20 / Q_MAX 2.013925e-02
# TIMESTEP 482 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 20 / Q_MAX 1.963060e-02
# TIMESTEP 483 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 20 / Q_MAX 1.396654e-02
# TIMESTEP 484 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 20 / Q_MAX 1.812343e-02
# TIMESTEP 485 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 2 / REWARD 20 / Q_MAX 1.746468e-02
# TIMESTEP 486 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 20 / Q_MAX 1.596098e-02
# TIMESTEP 487 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 20 / Q_MAX 1.681844e-02
# TIMESTEP 488 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 20 / Q_MAX 1.676336e-02
# TIMESTEP 489 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 20 / Q_MAX 1.814438e-02
# TIMESTEP 490 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 3 / REWARD 20 / Q_MAX 1.642649e-02
# TIMESTEP 491 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 20 / Q_MAX 1.563061e-02
# TIMESTEP 492 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 20 / Q_MAX 1.556232e-02
# TIMESTEP 493 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 1 / REWARD 20 / Q_MAX 1.727341e-02
# TIMESTEP 494 / STATE observe / LINES 0 / EPSILON 1.0 / ACTION 0 / REWARD 20 / Q_MAX 1.554011e-02
# ...
# TIMESTEP 2904 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 14 / Q_MAX 4.232556e+02
# TIMESTEP 2905 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 14 / Q_MAX 4.223169e+02
# TIMESTEP 2906 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 14 / Q_MAX 4.166311e+02
# TIMESTEP 2907 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 14 / Q_MAX 4.210349e+02
# TIMESTEP 2908 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 14 / Q_MAX 4.141057e+02
# TIMESTEP 2909 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 10 / Q_MAX 4.025580e+02
# TIMESTEP 2910 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 12 / Q_MAX 4.007993e+02
# TIMESTEP 2911 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 12 / Q_MAX 4.263073e+02
# TIMESTEP 2912 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 12 / Q_MAX 4.495470e+02
# TIMESTEP 2913 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 12 / Q_MAX 4.707968e+02
# TIMESTEP 2914 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 12 / Q_MAX 4.868308e+02
# TIMESTEP 2915 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 12 / Q_MAX 4.942221e+02
# TIMESTEP 2916 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 12 / Q_MAX 4.912027e+02
# TIMESTEP 2917 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 12 / Q_MAX 4.864410e+02
# TIMESTEP 2918 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 4 / Q_MAX 4.836585e+02
# TIMESTEP 2919 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 8 / Q_MAX 4.768919e+02
# TIMESTEP 2920 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 8 / Q_MAX 4.852534e+02
# TIMESTEP 2921 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 8 / Q_MAX 4.950085e+02
# TIMESTEP 2922 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 8 / Q_MAX 5.037253e+02
# TIMESTEP 2923 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 0 / Q_MAX 5.130019e+02
# TIMESTEP 2924 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 4 / REWARD 4 / Q_MAX 5.154614e+02
# TIMESTEP 2925 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 4 / REWARD 2 / Q_MAX 5.249810e+02
# TIMESTEP 2926 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 4 / REWARD 1 / Q_MAX 5.393182e+02
# TIMESTEP 2927 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 4 / REWARD 0 / Q_MAX 5.611406e+02
# TIMESTEP 2928 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 0 / Q_MAX 6.099476e+02
# TIMESTEP 2929 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 6.486014e+02
# TIMESTEP 2930 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 5.552171e+02
# TIMESTEP 2931 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 4.495712e+02
# TIMESTEP 2932 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 3.274012e+02
# TIMESTEP 2933 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 2.221981e+02
# TIMESTEP 2934 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 2.251195e+02
# TIMESTEP 2935 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 2.218521e+02
# TIMESTEP 2936 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 2.214237e+02
# TIMESTEP 2937 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 2.242494e+02
# TIMESTEP 2938 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 2.208470e+02
# TIMESTEP 2939 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 2.214720e+02
# TIMESTEP 2940 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 2.215402e+02
# TIMESTEP 2941 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 2.191909e+02
# TIMESTEP 2942 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 2.171662e+02
# TIMESTEP 2943 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 2.142440e+02
# TIMESTEP 2944 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 20 / Q_MAX 2.093049e+02
# TIMESTEP 2945 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 20 / Q_MAX 2.056168e+02
# TIMESTEP 2946 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 2.037452e+02
# TIMESTEP 2947 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.010790e+02
# TIMESTEP 2948 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.159536e+02
# TIMESTEP 2949 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.320122e+02
# TIMESTEP 2950 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.483394e+02
# TIMESTEP 2951 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.629142e+02
# TIMESTEP 2952 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.658318e+02
# TIMESTEP 2953 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.653166e+02
# TIMESTEP 2954 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.665281e+02
# TIMESTEP 2955 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.663126e+02
# TIMESTEP 2956 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.634898e+02
# TIMESTEP 2957 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.649717e+02
# TIMESTEP 2958 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.647726e+02
# TIMESTEP 2959 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.625133e+02
# TIMESTEP 2960 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.615403e+02
# TIMESTEP 2961 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.575243e+02
# TIMESTEP 2962 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 18 / Q_MAX 2.548030e+02
# TIMESTEP 2963 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 14 / Q_MAX 2.518246e+02
# TIMESTEP 2964 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 2.499250e+02
# TIMESTEP 2965 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 2.637181e+02
# TIMESTEP 2966 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 2.787289e+02
# TIMESTEP 2967 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 2.975599e+02
# TIMESTEP 2968 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.123160e+02
# TIMESTEP 2969 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.145248e+02
# TIMESTEP 2970 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.137299e+02
# TIMESTEP 2971 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.117802e+02
# TIMESTEP 2972 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.138963e+02
# TIMESTEP 2973 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.129283e+02
# TIMESTEP 2974 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.102360e+02
# TIMESTEP 2975 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.080403e+02
# TIMESTEP 2976 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.015663e+02
# TIMESTEP 2977 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 2.958174e+02
# TIMESTEP 2978 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 2.946770e+02
# TIMESTEP 2979 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 2.922555e+02
# TIMESTEP 2980 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 2.865305e+02
# TIMESTEP 2981 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 2.823480e+02
# TIMESTEP 2982 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 16 / Q_MAX 2.895502e+02
# TIMESTEP 2983 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 2.988076e+02
# TIMESTEP 2984 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.162518e+02
# TIMESTEP 2985 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.285054e+02
# TIMESTEP 2986 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.299701e+02
# TIMESTEP 2987 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.307001e+02
# TIMESTEP 2988 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.286208e+02
# TIMESTEP 2989 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.288912e+02
# TIMESTEP 2990 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.275219e+02
# TIMESTEP 2991 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.270363e+02
# TIMESTEP 2992 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.266430e+02
# TIMESTEP 2993 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 16 / Q_MAX 3.226981e+02
# TIMESTEP 2994 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 10 / Q_MAX 3.175491e+02
# TIMESTEP 2995 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.116566e+02
# TIMESTEP 2996 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.230912e+02
# TIMESTEP 2997 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.348057e+02
# TIMESTEP 2998 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.519887e+02
# TIMESTEP 2999 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.644844e+02
# TIMESTEP 3000 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.665070e+02
# TIMESTEP 3001 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.655745e+02
# TIMESTEP 3002 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.595931e+02
# TIMESTEP 3003 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.590559e+02
# TIMESTEP 3004 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 3 / REWARD 13 / Q_MAX 3.622671e+02
# TIMESTEP 3005 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.645854e+02
# TIMESTEP 3006 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.579436e+02
# TIMESTEP 3007 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.523102e+02
# TIMESTEP 3008 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.499555e+02
# TIMESTEP 3009 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.452816e+02
# TIMESTEP 3010 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.402067e+02
# TIMESTEP 3011 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.368600e+02
# TIMESTEP 3012 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.337267e+02
# TIMESTEP 3013 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.283337e+02
# TIMESTEP 3014 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.250413e+02
# TIMESTEP 3015 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.364162e+02
# TIMESTEP 3016 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.464546e+02
# TIMESTEP 3017 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.637650e+02
# TIMESTEP 3018 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 0 / REWARD 13 / Q_MAX 3.762953e+02
# TIMESTEP 3019 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.785501e+02
# TIMESTEP 3020 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.789089e+02
# TIMESTEP 3021 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.724642e+02
# TIMESTEP 3022 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.809419e+02
# TIMESTEP 3023 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.725826e+02
# TIMESTEP 3024 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 13 / Q_MAX 3.774626e+02
# TIMESTEP 3025 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 3.732708e+02
# TIMESTEP 3026 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 11 / Q_MAX 3.743087e+02
# TIMESTEP 3027 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 11 / Q_MAX 3.888455e+02
# TIMESTEP 3028 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 11 / Q_MAX 4.043678e+02
# TIMESTEP 3029 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 11 / Q_MAX 4.214690e+02
# TIMESTEP 3030 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 4 / REWARD 7 / Q_MAX 4.266789e+02
# TIMESTEP 3031 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 4.256111e+02
# TIMESTEP 3032 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 4.343038e+02
# TIMESTEP 3033 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 4.467374e+02
# TIMESTEP 3034 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 4.670106e+02
# TIMESTEP 3035 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 4.813703e+02
# TIMESTEP 3036 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 4.858030e+02
# TIMESTEP 3037 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 4.820230e+02
# TIMESTEP 3038 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 4.823900e+02
# TIMESTEP 3039 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 4.834870e+02
# TIMESTEP 3040 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 4.843590e+02
# TIMESTEP 3041 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 4.862611e+02
# TIMESTEP 3042 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.178237e+02
# TIMESTEP 3043 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.449765e+02
# TIMESTEP 3044 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.722460e+02
# TIMESTEP 3045 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 3 / REWARD 9 / Q_MAX 5.945258e+02
# TIMESTEP 3046 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.926130e+02
# TIMESTEP 3047 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.859598e+02
# TIMESTEP 3048 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.795524e+02
# TIMESTEP 3049 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.831263e+02
# TIMESTEP 3050 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.744634e+02
# TIMESTEP 3051 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.714436e+02
# TIMESTEP 3052 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.655735e+02
# TIMESTEP 3053 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.585318e+02
# TIMESTEP 3054 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.559232e+02
# TIMESTEP 3055 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.538065e+02
# TIMESTEP 3056 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.515090e+02
# TIMESTEP 3057 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.532663e+02
# TIMESTEP 3058 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.662526e+02
# TIMESTEP 3059 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 5.872946e+02
# TIMESTEP 3060 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 6.020772e+02
# TIMESTEP 3061 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 6.186840e+02
# TIMESTEP 3062 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 9 / Q_MAX 6.230635e+02
# TIMESTEP 3063 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 3 / Q_MAX 6.158226e+02
# TIMESTEP 3064 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 6 / Q_MAX 6.089843e+02
# TIMESTEP 3065 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 6 / Q_MAX 6.093860e+02
# TIMESTEP 3066 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 6 / Q_MAX 6.259136e+02
# TIMESTEP 3067 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 4 / Q_MAX 6.290182e+02
# TIMESTEP 3068 / STATE train / LINES 0 / EPSILON 0.05 / ACTION 5 / REWARD 5 / Q_MAX 6.483456e+02
